# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sps
import math
# %matplotlib inline

# %%
size=100
gamma = 0.95
X = sps.norm.rvs(size=100, loc=0, scale=1)
print(X)
print(X[:1])
print(len(X))
# Out:
# [-0.28298947 -0.72709826  1.33476291  1.01073473 -1.17267825 -0.98277748
#  -0.19423883 -1.12942852  1.38677378 -0.84269962  1.47479532  0.2680102
#   0.26252006 -0.23878751 -0.06851624  0.61124155  0.47854152  0.20740954
#   0.15136506 -0.41061405  1.46592798 -0.3375628   0.83090092  0.18593301
#   0.95527945  0.94495465 -0.01528032  1.87097637  0.88240672  0.4924857
#   0.09890324  0.94089285  1.94150015  1.94002299  0.79422747  1.21570616
#   0.13533634  1.39603181 -1.01779119  0.88413107  0.80222953 -0.33979656
#  -1.97739454 -0.20888707  0.66652489 -0.93823735 -0.06776711  1.28492924
#  -1.04205516  1.27557626  0.54167655 -0.23609205 -1.8585487  -0.18152984
#   2.13036558 -0.86296235 -0.64946393 -0.73981423  1.49629056  1.03543991
#   0.68659653 -0.5385322   1.31940454  0.39787655  0.4190163   1.98366925
#   1.20001845  1.80060097 -0.43966631 -0.55617495 -1.03476947  0.32546384
#   0.27680871  0.76708118 -1.42595691  1.53711577  0.38447908  1.93408404
#  -0.41332816 -0.5277045  -0.52018039 -0.7353282   1.51971192  0.46926435
#   1.77053367 -0.40810243 -0.85030109 -0.10603467 -1.33707221  0.56235912
#  -0.61570064 -0.18850957 -0.25765666 -2.40454975  0.00610786  0.25214251
#  -0.64333252 -0.72150966  0.49762404  0.12377192]
# [-0.28298947]
# 100

# %% [markdown]
# ### Строим доверительные интервалы:
# ## (a) Для $a$ при известном $\sigma^2$:
# # $\left(\overline{X}-\sqrt{\frac{\overline S^2}{n-1}}z_{\frac{1+\gamma}{2}}, \overline{X}+\sqrt{\frac{\overline S^2}{n-1}}z_{\frac{1+\gamma}{2}} \right)$, где $z_{\frac{1+\gamma}{2}}$ - квантиль уровня ${\frac{1+\gamma}{2}}$ из
# # распределения Стьюдента $T_{n-1}$

# %%
quant = [sps.t.ppf((1+gamma)*1./2, i - 1) for i in range(2, size, 1)]
# print(len(quant1))
# quant = sps.t.ppf((1+gamma)*1./2, size - 1) 
print(math.sqrt(4))

left = [X[:i].mean()-math.sqrt(((X[:i]**2).mean()+(X[:i].mean())**2)/(i-1))*quant[i] for i in range(2, size, 1)]
print(len(left))
right = [X[:i].mean()-math.sqrt(((X[:i]**2).mean()+(X[:i].mean())**2)/(i-1))*quant1[i] for i in range(2, size-2, 1)]
# Out:
# 98
# 2.0
# 98

# %% [markdown]
# ## Построим график:

# %%
plt.figure(figsize = (15, 10))
plt.ylim(-1.5, 0)
plt.matplotlib.pyplot.fill_between(range(size-2), left, right, facecolor='blue', alpha = 0.7)
